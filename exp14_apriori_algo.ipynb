# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules

df=pd.read_csv('Online_Retail.csv',encoding='ISO-8859-1')
df['Description']=df['Description'].str.strip()
df.dropna(subset=['InvoiceNo'],inplace=True)

basket=(
    df[df['Country']=="France"]
    .groupby(['InvoiceNo','Description'])['Quantity']
    .sum()
    .unstack()
    .reset_index()
    .fillna(0)
    .set_index('InvoiceNo')
)

def encode_units(x):
    return 1 if x>=1 else 0

basket_sets=basket.map(encode_units)
frequent_itemsets=apriori(basket_sets,min_support=0.07,use_colnames=True)
rules=association_rules(frequent_itemsets,metric="lift",min_threshold=1)
print(frequent_itemsets)
print(rules)
# Out:
#      support                                           itemsets
# 0   0.082430                       (ALARM CLOCK BAKELIKE GREEN)
# 1   0.086768                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.080260                         (ALARM CLOCK BAKELIKE RED)
# 3   0.084599                             (DOLLY GIRL LUNCH BOX)
# 4   0.082430                          (JUMBO BAG RED RETROSPOT)
# ..       ...                                                ...
# 62  0.071584  (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE, PL...
# 63  0.071584  (POSTAGE, SET/6 RED SPOTTY PAPER CUPS, SET/20 ...
# 64  0.071584  (POSTAGE, SET/6 RED SPOTTY PAPER PLATES, SET/2...
# 65  0.086768  (POSTAGE, SET/6 RED SPOTTY PAPER CUPS, SET/6 R...
# 66  0.084599  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
#
# [67 rows x 2 columns]
#                                           antecedents  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                                           (POSTAGE)
# 2                         (ALARM CLOCK BAKELIKE PINK)
# 3                                           (POSTAGE)
# 4                                           (POSTAGE)
# ..                                                ...
# 91  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 92  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 93               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 94                      (SET/6 RED SPOTTY PAPER CUPS)
# 95                    (SET/6 RED SPOTTY PAPER PLATES)
#
#                                           consequents  antecedent support  \
# 0                                           (POSTAGE)            0.082430
# 1                        (ALARM CLOCK BAKELIKE GREEN)            0.650759
# 2                                           (POSTAGE)            0.086768
# 3                         (ALARM CLOCK BAKELIKE PINK)            0.650759
# 4                          (ALARM CLOCK BAKELIKE RED)            0.650759
# ..                                                ...                 ...
# 91                      (SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 92               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.104121
# 93  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...            0.112798
# 94  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...            0.117137
# 95  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...            0.108460
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0.650759  0.071584    0.868421  1.334474               1.0
# 1             0.082430  0.071584    0.110000  1.334474               1.0
# 2             0.650759  0.075922    0.875000  1.344583               1.0
# 3             0.086768  0.075922    0.116667  1.344583               1.0
# 4             0.080260  0.073753    0.113333  1.412072               1.0
# ..                 ...       ...         ...       ...               ...
# 91            0.117137  0.084599    0.975000  8.323611               1.0
# 92            0.112798  0.084599    0.812500  7.203125               1.0
# 93            0.104121  0.084599    0.750000  7.203125               1.0
# 94            0.086768  0.084599    0.722222  8.323611               1.0
# 95            0.086768  0.084599    0.780000  8.989500               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.017942    2.654230       0.273157  0.108197   0.623243    0.489211
# 1   0.017942    1.030978       0.717674  0.108197   0.030047    0.489211
# 2   0.019457    2.793926       0.280624  0.114754   0.642081    0.495833
# 3   0.019457    1.033848       0.733807  0.114754   0.032740    0.495833
# 4   0.021523    1.037300       0.835586  0.112211   0.035959    0.516126
# ..       ...         ...            ...       ...        ...         ...
# 91  0.074435   35.314534       0.963457  0.709091   0.971683    0.848611
# 92  0.072854    4.731743       0.961259  0.639344   0.788661    0.781250
# 93  0.072854    3.583514       0.970660  0.639344   0.720944    0.781250
# 94  0.074435    3.287636       0.996598  0.709091   0.695830    0.848611
# 95  0.075188    4.151055       0.996881  0.764706   0.759097    0.877500
#
# [96 rows x 14 columns]
# c:\Users\alang\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:175: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
